# %%
import sys
import os

# Add the root folder to sys.path so you can import scripts/
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
from scripts.telegram_scraper import scrape_channel
